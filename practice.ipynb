# %%
from typing import List
from random import randint
titles = [
    'Two Sum','Two Sum 2', 'Best Time to Buy and Sell Stock', 'Contains Duplicate', 'Product of Array Excelpt Self', 
    'Maximum Subarray', 'Maximum Product Subarray', 'Minimum in rotated Sorted Array', 'Search in rotated sorted array', 
    'Threesum to Zero', 'Container with Most Water'
]

for i in range(3):
    random_title = randint(0, len(titles)-1)
    print(titles[random_title])
# Out:
# Minimum in rotated Sorted Array
# Maximum Product Subarray

# %%
def max_profit(arr: List[int]) -> int:
    return 

max_profit([7, 1, 5, 3, 6, 4])
# Out:
# 5

# %%
def two_sum_2(arr: List[int], target: int) -> List[int]:
    print("Target is not in the array")

two_sum_2([1,2,3,4,5], 5)
# Out:
# 6
# 5
# [1, 4]

# %%
def product_arr_noSelf(arr: List[int]) -> List[int]:
    return
product_arr_noSelf([4, 5, 6, 7])
# Out:
# [210, 168, 140, 120]

# %%
def find_min_rotate_arr(arr: List[int]) -> int:
    left, right = 0, len(arr) - 1
    output = arr[0]
    while left <= right:
        if arr[left] < arr[right]:
            output = min(output, arr[left])
            break
        
        middle = (right - left) // 2
        print(f"left:{left}, right:{right}, middle: {middle} - value in the arr: {arr[middle]}")
        
        output = min(output, arr[middle])
        if arr[middle] > arr[left]:
            left = middle + 1
        else:
            right = middle - 1
            
    return output
        

find_min_rotate_arr([4, 5, 6, 7, 0, 1, 2])
# find_min_sort_arr([3,4,5,1,2])
# Out:
# left:0, right:6, middle: 3 - value in the arr: 7
# 0

# %%
def findMin(arr: List[int]) -> int:
    output = arr[0]  # Initialize the output to the first element of the array.
    left, right = 0, len(arr) - 1  # Initialize two pointers, 'left' and 'right,' to the start and end of the array.
    
    while left <= right:  # Perform a binary search until 'left' is less than or equal to 'right.'
        if arr[left] < arr[right]:  # If the array is sorted in ascending order, set the output to the leftmost element and break.
            output = min(output, arr[left])
            break
        
        middle = (right - left) // 2  # Calculate the middle index.
        print(f"middle: {middle} - value in the arr: {arr[middle]}")
        output = min(output, arr[middle])  # Update the output with the minimum of the current output and the middle element.
        
        if arr[middle] > arr[left]:  # Check if the middle element is greater than the leftmost element.
            left = middle + 1  # If so, update 'left' to be one past the middle (move right).
        else:
            right = middle - 1  # Otherwise, update 'right' to be one before the middle (move left).
    
    return output  # Return the minimum element found.

findMin([4,5,6,7,0,1,2])
# Out:
# middle: 3 - value in the arr: 7
# 0

# %%
def search_rotate_arr(arr: List[int], target: int) -> int:
    return -1

search_rotate_arr([4,5,6,7,1,2,3], 5)
# Out:
# 5

# %%
def max_product_subarr(arr: List[int]) -> int:
    curMin, curMax = 1, 1
    output = max(arr)
    for n in arr:
        if n == 0:
            curMin, curMax = 1
        temp = curMax
        curMax = max(curMax*n, n, curMin*n)
        curMin = min(temp*n, n, curMin*n)
        output = max(output, curMax) 
        print(output)
    return output

max_product_subarr([2, 3, -2, 4])
# Out:
# 4
# 6
# 6
# 6
# 6

# %%
def three_sum_zero(arr:List[int]) -> List[int]:
    arr.sort()
    output = []
    for index, value in enumerate(arr):
        if index > 0 and value == arr[index - 1]: #if index is positive and current value is the same as the previous, skip it
            continue
        # pointer
        left, right = index + 1, len(arr) - 1
        while left < right:
            # sum current value and the value of the poiters
            sum = value + arr[left] + arr[right]
            if sum > 0:
                right -= 1
            elif sum < 0:
                left += 1
            else:
                output.append([value, arr[left], arr[right]])
                left += 1
                # while arr[left] == arr[left-1] and left < right:
                #     left += 1
    return output

three_sum_zero([-3,3,4,-3,1,2])
# Out:
# [[-3, 1, 2]]

# %%
def maxArea(arr: List[int]) -> int:
    return
maxArea([2,3,5,8,1,3,4,5,9])
# Out:
# 72
